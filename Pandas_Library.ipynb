# %% [markdown]
# <a href="https://colab.research.google.com/github/AshrafalKhalique/Skill-chef---Python/blob/main/Pandas_Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **What is Pandas?**
# Pandas is open-source Python library which is used for data manipulation and analysis. It has functions for analyzing, cleaning, exploring, and manipulating data.

# %% [markdown]
# Installing Pandas in Python

# %%
# !pip install pandas

# %% [markdown]
# Once installed, import the library with the alias pd

# %%
import pandas as pd

# %% [markdown]
# Checking Pandas Version

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# # Pandas Series

# %%
# Series of fruits
fruits = pd.Series(['Apple', 'Banana', 'Mango', 'Strawberry'])

print(fruits)
# Out:
# 0         Apple
# 1        Banana
# 2         Mango
# 3    Strawberry
# dtype: object

# %% [markdown]
# # Pandas Dataframe

# %%
data = {
    'Name': ['Arun', 'Bipasha', 'Sakib'],
    'Age': [25, 30, 22],
    'City': ['Dhaka', 'Rajshahi', 'Cumilla']
}

df_data = pd.DataFrame(data)
print(df_data)
# Out:
#       Name  Age      City
# 0     Arun   25     Dhaka
# 1  Bipasha   30  Rajshahi
# 2    Sakib   22   Cumilla

# %% [markdown]
# # Saving the new dataframe

# %%
df_data.to_csv('df_data.csv', index=False)

# %%
df_data.to_excel('df_data.xlsx', index=False)

# %% [markdown]
# # Pandas Reading Files & View Techniques

# %%
# Load the dataset
data_path = 'F:\Research\OrchidResearch\Obesity - Journal\Dataset\obesity.csv'  # Replace with your actual path
df = pd.read_csv(data_path)

# %%
from google.colab import drive
drive.mount('/content/drive')

# Load the dataset
data_path = '/content/drive/MyDrive/OrchidResearch/Dataset/ObesityDataSet.csv'  # Replace with your actual path
df = pd.read_csv(data_path)
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
uploaded = files.upload()  # Upload your csv

# Extract the filename
filename = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-398c67ef-ba23-4dae-ba0b-dd39ef655945" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-398c67ef-ba23-4dae-ba0b-dd39ef655945">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# First 3 row
df.head(100)
# Out:
#     Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0   Female  21.0    1.62    64.0                            yes   no   2.0
# 1   Female  21.0    1.52    56.0                            yes   no   3.0
# 2     Male  23.0    1.80    77.0                            yes   no   2.0
# 3     Male  27.0    1.80    87.0                             no   no   3.0
# 4     Male  22.0    1.78    89.8                             no   no   2.0
# ..     ...   ...     ...     ...                            ...  ...   ...
# 95    Male  26.0    1.70    70.0                            yes   no   3.0
# 96  Female  23.0    1.66    60.0                            yes   no   2.0
# 97  Female  21.0    1.52    42.0                             no   no   3.0
# 98  Female  21.0    1.52    42.0                             no   no   3.0
# 99    Male  23.0    1.72    70.0                             no   no   2.0
#
#     NCP        CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# ...

# %%
# Last 3 row
df.tail(10)
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 2101  Female  25.722004  1.628470  107.218949                            yes
# 2102  Female  25.765628  1.627839  108.107360                            yes
# 2103  Female  21.016849  1.724268  133.033523                            yes
# 2104  Female  21.682367  1.732383  133.043941                            yes
# 2105  Female  21.285965  1.726920  131.335786                            yes
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O SCC       FAF       TUE  \
# ...

# %%
# Data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
# Calculate the mean value
df.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2904130479.py in <cell line: 0>()
#       1 # Calculate the mean value for each column
# ----> 2 df.mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
# Calculate the mean value for each row:
df.mean(axis=3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     575         try:
# --> 576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
#
# KeyError: 3
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4028859579.py in <cell line: 0>()
#       1 # Calculate the mean value for each row:
# ----> 2 df.mean(axis=3)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
# ...

# %%
# Calculate the mean value for each coloumn:
df['Height'].mean()
# Out:
# np.float64(1.7016773533870204)

# %% [markdown]
# # Pandas Select, Drop, Delete

# %%
# Select
Select_first = df['Age']
print(Select_first)
# Out:
# 0       21.000000
# 1       21.000000
# 2       23.000000
# 3       27.000000
# 4       22.000000
#           ...
# 2106    20.976842
# 2107    21.982942
# 2108    22.524036
# 2109    24.361936
# 2110    23.664709
# Name: Age, Length: 2111, dtype: float64

# %%
# Select Multiple Coloumn
Age_Height = df[['Age', 'Height']]
print(Age_Height)
# Out:
#             Age    Height
# 0     21.000000  1.620000
# 1     21.000000  1.520000
# 2     23.000000  1.800000
# 3     27.000000  1.800000
# 4     22.000000  1.780000
# ...         ...       ...
# 2106  20.976842  1.710730
# 2107  21.982942  1.748584
# 2108  22.524036  1.752206
# 2109  24.361936  1.739450
# 2110  23.664709  1.738836
#
# [2111 rows x 2 columns]

# %%
df_dropped = df.drop(['Age','Gender'], axis=1)
print(df_dropped)
# Out:
#         Height      Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0     1.620000   64.000000                            yes   no   2.0  3.0
# 1     1.520000   56.000000                            yes   no   3.0  3.0
# 2     1.800000   77.000000                            yes   no   2.0  3.0
# 3     1.800000   87.000000                             no   no   3.0  3.0
# 4     1.780000   89.800000                             no   no   2.0  1.0
# ...        ...         ...                            ...  ...   ...  ...
# 2106  1.710730  131.408528                            yes  yes   3.0  3.0
# 2107  1.748584  133.742943                            yes  yes   3.0  3.0
# 2108  1.752206  133.689352                            yes  yes   3.0  3.0
# 2109  1.739450  133.346641                            yes  yes   3.0  3.0
# 2110  1.738836  133.472641                            yes  yes   3.0  3.0
#
#            CAEC SMOKE      CH2O  SCC       FAF       TUE        CALC  \
# ...

# %% [markdown]
# # Pandas Joining, Merging, Concatenating

# %%
df1 = pd.DataFrame({'ফল': ['আপেল'], 'দাম': [100]})
df2 = pd.DataFrame({'ফল': ['কলা'], 'দাম': [30]})
print(df1)
print(df2)
# সারি বরাবর নিচে নিচে জুড়ে দেওয়া
combined_df = pd.concat([df1, df2])
print(combined_df)
# Out:
#      ফল  দাম
# 0  আপেল  100
#     ফল  দাম
# 0  কলা   30
#      ফল  দাম
# 0  আপেল  100
# 0   কলা   30

# %%
# উদাহরণ: 'ID' কলামের ভিত্তিতে দুটি টেবিল merge করা
data_A = pd.DataFrame({'ID': [1, 2], 'নাম': ['ক', 'খ']})
data_B = pd.DataFrame({'ID': [1, 3], 'স্কোর': [90, 85]})

# ID-র ভিত্তিতে Merging (যারা উভয় টেবিলে আছে)
merged_df = pd.merge(data_A, data_B, on='ID', how='inner')
print(merged_df)
# Out:
#    ID নাম  স্কোর
# 0   1   ক     90

# %% [markdown]
# # Working with Missing Data
#
#
# 1.   Drop
# 2.   Fill

# %%
import numpy as np
data_with_nan = {'A': [1, 2, np.nan], 'B': [5, np.nan, 10], 'C': [1, 2, 3]}
df_nan = pd.DataFrame(data_with_nan)
print(df_nan)
# Out:
#      A     B  C
# 0  1.0   5.0  1
# 1  2.0   NaN  2
# 2  NaN  10.0  3

# %%
df_dropped = df_nan.dropna()
print(df_dropped)
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df_filled_zero = df_nan.fillna(0)
print(df_filled_zero)
# Out:
#      A     B  C
# 0  1.0   5.0  1
# 1  2.0   0.0  2
# 2  0.0  10.0  3

# %%
mean_b = df_nan['B'].mean()
mean_a = df_nan['A'].mean()
df_nan['B'].fillna(mean_b, inplace=True) # inplace=True মানে আসল ডেটাফ্রেমে পরিবর্তন হবে
df_nan['A'].fillna(mean_a, inplace=True)
print(df_nan)
# Out:
#      A     B  C
# 0  1.0   5.0  1
# 1  2.0   7.5  2
# 2  1.5  10.0  3
# /tmp/ipython-input-2619190824.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_nan['B'].fillna(mean_b, inplace=True) # inplace=True মানে আসল ডেটাফ্রেমে পরিবর্তন হবে
# /tmp/ipython-input-2619190824.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# # Handling Duplicate Values

# %%
data_dup = {'ID': [1, 2, 2, 3], 'Score': [90, 85, 85, 92]}
df_dup = pd.DataFrame(data_dup)
print(df_dup)
# Out:
#    ID  Score
# 0   1     90
# 1   2     85
# 2   2     85
# 3   3     92

# %%
df_unique = df_dup.drop_duplicates()
print(df_unique)
# Out:
#    ID  Score
# 0   1     90
# 1   2     85
# 3   3     92
